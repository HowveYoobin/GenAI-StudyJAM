# %%
from vertexai.preview.generative_models import GenerativeModel

model = GenerativeModel("gemini-1.0-pro")

prompt = """
Cymbal Direct is partnering with an outdoor gear retailer. They\'re launching a new line of products designed to encourage young people to explore the outdoors. Help them create catchy taglines for this product line.

input: Write a tagline for a durable backpack designed for hikers that makes them feel prepared. Consider styles like minimalist.
output: Built for the Journey: Your Adventure

input: Write a tagline for a durable backpack designed for hikers that makes them want to go to the nature. Must include a word 'nature'
output: Best for your nature adventure

"""

responses = model.generate_content(
    prompt,
    generation_config={
        "temperature": 0.5,
        "max_output_tokens": 2048,
        "top_p": 1.0,
        "top_k": 40,
    },
    stream=True
    )

for response in responses:
    print(response.text)
# Out:
# ## Taglines
#  for Cymbal Direct's Outdoor Gear:
#
# **For the minimalist backpack:**
#
# * **Built for the Journey
# : Your Adventure Awaits.**
# * **Less is More: Pack Light, Explore Far.**
# * **Minimalist Design,
#  Maximum Exploration.**
# * **Unburdened Adventure: Your Journey Starts Here.**
# * **Go Further, Pack Lighter: The Minimalist's Backpack.**
#
# **For the nature-focused backpack:**
#
# * **Embrace the Wild: Your Nature Awaits.**
# * **
# Get Closer to Nature: Explore with Confidence.**
# * **Adventure Starts Here: Your Nature Companion.**
# * **Built for the Elements: Your Wilderness Ally.**
# * **Leave Your Mark on Nature, Not Your Backpack.**
#
# **Additional taglines:**
#
#
# * **Cymbal Direct: Gear Up for Your Next Adventure.**
# * **Explore More, Worry Less: Cymbal Direct Outdoor Gear.**
# * **Adventure Ready: Cymbal Direct Equips Your Journey.**
# * **Built to Last, Made to Explore: Cymbal Direct.**
# * **Unleash Your Inner Explorer: Cymbal Direct Outdoor Gear.**
#
# **Taglines with a call to action:**
#
# * **
# Get Outside: Explore with Cymbal Direct.**
# * **Adventure Awaits: Gear Up with Cymbal Direct.**
# * **Start Your Journey: Cymbal Direct Outdoor Gear.**
# * **Leave the Ordinary Behind: Explore with Cymbal Direct.**
# * **Make Memories, Not Footprints: Cymbal Direct Outdoor Gear.**
#
# **Taglines with a sense of community:**
#
# * **Join the Adventure: Cymbal Direct Outdoor
#  Gear.**
# * **Explore Together: Cymbal Direct Connects You to Nature.**
# * **Adventure Starts with Cymbal Direct: Share Your Journey.**
# * **Build Memories, Not Walls: Cymbal Direct Outdoor Gear.**
# * **Leave the World Behind, Find Your Tribe: Cymbal Direct.**
#
# **Taglines with a focus on sustainability:**
#
# * **Explore Responsibly: Cymbal Direct Eco-Friendly Gear.**
# * **Leave No Trace: Adventure Sustainably with Cymbal Direct.**
# * **
# Respect the Earth, Explore with Cymbal Direct.**
# * **Built to Last, Made to Minimize Impact: Cymbal Direct.**
# * **Adventure with a Conscience: Cymbal Direct Eco-Gear.**
#
# **Taglines with a humorous tone:**
#
# * **Get Lost (But Not Really): Cymbal Direct Outdoor Gear.**
# * **Adventure Proof: Guaranteed to Survive Your Next Mishap.**
# * **Leave the City Behind (Your Phone Can Wait): Cymbal Direct.**
# * **Nature is Calling: Answer with Cymbal Direct.**
# * **Get Outside, Even if it's Just to Escape the Wi-Fi
# : Cymbal Direct.**
